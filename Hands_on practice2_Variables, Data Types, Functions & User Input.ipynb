# %% [markdown]
# ## Creating Variables

# %%
name = "Motunrayo"
age = 22
country = "Nigeria"
print(name)
print(age)
print(country)
# Out:
# Motunrayo
# 22
# Nigeria

# %% [markdown]
# ## Salary Calculation

# %%
monthly_salary = 180000
bonus = 35000
total_salary = monthly_salary + bonus
print(total_salary)
# Out:
# 215000

# %% [markdown]
# ## User Input

# %%
name = input("Enter your name:")
programming_language = input("Enter your favourite programming language:")
print("Hello", name)
print("My favourite programming language is", programming_language)
# Out:
# Enter your name: Motunrayo
# Enter your favourite programming language: Python
# Hello Motunrayo
# My favourite programming language is Python

# %% [markdown]
# ## Working with Data Types

# %%
age = 25
weight = 10.2
country = "Nigeria"
valid = True
print(type(age))
print(type(weight))
print(type(country))
print(type(valid))
# Out:
# <class 'int'>
# <class 'float'>
# <class 'str'>
# <class 'bool'>

# %% [markdown]
# ## Dynamic Typing

# %%
country = 36
print(type(country))
country = "Nigeria"
print(type(country))
# Out:
# <class 'int'>
# <class 'str'>

# %% [markdown]
# # STUDENT INFORMATION CARD

# %%
name = input("Enter your name:")
age = input("Enter your age:")
course = input("Enter your course:")
country = input("Enter your country:")
print("Name : ", name)
print("Age : " ,age)
print("Course : " ,course)
print("Country : " ,country)
print(type(name))
print(type(age))
print(type(course))
print(type(country))
age = int(input("Enter your age:"))
print("Age : " ,age)
print(type(age))
# Out:
# Enter your name: Motunrayo
# Enter your age: 25
# Enter your course: Python Programming
# Enter your country: Nigeria
# Name :  Motunrayo
# Age :  25
# Course :  Python Programming
# Country :  Nigeria
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# Enter your age: 25
# Age :  25
# <class 'int'>
