# %% [markdown]
# ## Customer Registration System

# %%
name = "Motunrayo"
email = "afuwapetaofikat@gmail.com"
phone = 9022531820
country = "Nigeria"
occupation = "Student"
print("                     ")
print("   Customer Registration")
print("                       ")
print(" Name : " , name)
print(" Email : " , email)
print(" Phone : " , phone)
print(" Country : " , country)
print(" Occupation : " , occupation)
# Out:
#
#    Customer Registration
#
#  Name :  Motunrayo
#  Email :  afuwapetaofikat@gmail.com
#  Phone :  9022531820
#  Country :  Nigeria
#  Occupation :  Student

# %% [markdown]
# ## Hospital Patient Record

# %%
patient_record = """PATIENT RECORD
Patient : Olamide
Doctor: Mr Dayo
Diagnosis: Malaria
Blood group: O+
Hospital: Divine Mercy Hospital"""
print(patient_record)
# Out:
# PATIENT RECORD
# Patient : Olamide
# Doctor: Mr Dayo
# Diagnosis: Malaria
# Blood group: O+
# Hospital: Divine Mercy Hospital

# %% [markdown]
# ## AI Prompt Builder

# %%
prompt = """You are an AI Assistant.

Analyze customer feedback.

Identify common complaints.

Provide recommendations.

Generate a summary report.

Use clear, professional language and organize the results with headings and bullet points."""

print(prompt)
# Out:
# You are an AI Assistant.
#
# Analyze customer feedback.
#
# Identify common complaints.
#
# Provide recommendations.
#
# Generate a summary report.
#
# Use clear, professional language and organize the results with headings and bullet points.

# %% [markdown]
# ## Customer Feedback Management System

# %%
customer_name = "Sarah Johnson"
product_name = "Wireless Mouse"
product_category = "Computer Accessories"
customer_rating = "5 Stars"
customer_review = 'The product arrived on time, was easy to install, and exceeded my expectations.\n"I would definitely recommend it to others."'

welcome_message = '''
Welcome to Insight Retail Technologies
Customer Feedback Management System
'''

print(welcome_message)

# Feedback report (using triple double quotes)
feedback_report = f"""
========================================
       CUSTOMER FEEDBACK REPORT
========================================

Customer Name : {customer_name}
Product       : {product_name}
Category      : {product_category}
Rating        : {customer_rating}

Customer Review
----------------------------------------
{customer_review}

========================================
Thank you for your feedback!
========================================

Insight Retail Technologies
Support Email: support@insightretail.com
"""

print(feedback_report)
# Out:
# Welcome to Insight Retail Technologies
# Customer Feedback Management System
#
#
# ...
#        CUSTOMER FEEDBACK REPORT
# ...
#
# Customer Name : Sarah Johnson
# Product       : Wireless Mouse
# Category      : Computer Accessories
# Rating        : 5 Stars
#
# Customer Review
# ----------------------------------------
# The product arrived on time, was easy to install, and exceeded my expectations.
# "I would definitely recommend it to others."
#
# ...
# Thank you for your feedback!
# ...
#
# Insight Retail Technologies
# Support Email: support@insightretail.com
