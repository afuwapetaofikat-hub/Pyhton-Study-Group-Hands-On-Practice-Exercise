# %% [markdown]
# ## Secure Login System

# %%
username_correct = True
password_correct = True
account_locked = False 
if username_correct and password_correct and not account_locked:
    print("Access granted")
else:
    print("Access denied")
# Out:
# Access granted

# %% [markdown]
# ## University Scholarship Eligibility

# %%
exam_score = 85
participated = True
low_income = False
if exam_score >= 80 and (participated or low_income):
    print("Congratulations!")
    print("Scholarship Approved")
else:
    print("Scholarship Not Approved")
# Out:
# Congratulations!
# Scholarship Approved

# %% [markdown]
# ## Smart Server Health Monitor

# %%
cpu_usage = 75
memory_usage = 92
disk_usage = 60
if cpu_usage > 90 or memory_usage > 90 or disk_usage > 95:
    print("Critical Alert!")
else:
    print("System Healthy")
# Out:
# Critical Alert!

# %% [markdown]
# ## Bonus Challenge

# %%
#Scenerio 1
logged_in = True
item_in_stock = True
saved_payment = True
enough_wallet_balance = False
account_suspended = False
if logged_in and item_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended:
    print("Order Confirmed")
else:
    print("Order Failed")

# Scenario 2
logged_in = False
item_in_stock = True
saved_payment = True
enough_wallet_balance = True
account_suspended = False

if logged_in and item_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended:
    print("Order Confirmed")
else:
    print("Order Failed")


# Scenario 3
logged_in = True
item_in_stock = False
saved_payment = True
enough_wallet_balance = True
account_suspended = False

if logged_in and item_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended:
    print("Order Confirmed")
else:
    print("Order Failed")


# Scenario 4
logged_in = True
item_in_stock = True
saved_payment = False
enough_wallet_balance = False
account_suspended = False

if logged_in and item_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended:
    print("Order Confirmed")
else:
    print("Order Failed")


# Scenario 5
logged_in = True
item_in_stock = True
saved_payment = True
enough_wallet_balance = True
account_suspended = True

if logged_in and item_in_stock and (saved_payment or enough_wallet_balance) and not account_suspended:
    print("Order Confirmed")
else:
    print("Order Failed")
# Out:
# Order Confirmed
# Order Failed
# Order Failed
# Order Failed
# Order Failed
