# %% [markdown]
# # How to use print

# %%
print("Hello, World!")
print("My name is Afuwape Taofikat")
print("I am learning Python")
print("Programming is exciting!")
# Out:
# Hello, World!
# My name is Afuwape Taofikat
# I am learning Python
# Programming is exciting!

# %% [markdown]
# # Using multiple print statement

# %%
print("My favourite food is Beans")
print("My favourite Movie is Vagabond")
print("My favourite Sport is Basketball")
print("My favourite colour is Brown")
# Out:
# My favourite food is Beans
# My favourite Movie is Vagabond
# My favourite Sport is Basketball
# My favourite colour is Brown

# %% [markdown]
# # Calculations

# %%
print(15 + 5)
print(30 - 12)
print(9 * 8)
print(72 / 9)
print(18 % 5)
print(10 // 3)
print(5 ** 2)
# Out:
# 20
# 18
# 72
# 8.0
# 3
# 3
# 25

# %% [markdown]
# # Understanding comments

# %%
# Display programming language
print("Python")

# Display the subject
print("Programming")

# Display the lesson number
print("Lesson One")
# Out:
# Python
# Programming
# Lesson One

# %% [markdown]
# # Mini challenge

# %%
#display my name
print("My name is Afuwape Taofikat")

#my dream career
print("I would love to be an entrepreneur")

#my country
print("I am a citizen of Nigeria")

print(25 + 75)
print(40 // 6)
print(8 ** 2)
# Out:
# My name is Afuwape Taofikat
# I would love to be an entrepreneur
# I am a citizen of Nigeria
# 100
# 6
# 64
